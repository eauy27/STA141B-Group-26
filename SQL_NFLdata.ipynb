# %%
import pandas as pd
import sqlite3 as sql
import openpyxl

avg_stats = ['AVG_QB','AVG_WR','AVG_TE','AVG_RB','AVG_DE','AVG_LB','AVG_OLB','AVG_ILB','AVG_CB','AVG_DB','AVG_S','AVG_FS','AVG_DT','AVG_K'] # List of average stats for each NFL position
total_stats = ['TOT_QB','TOT_WR','TOT_TE','TOT_RB','TOT_DE','TOT_LB','TOT_OLB','TOT_ILB','TOT_CB','TOT_DB','TOT_S','TOT_FS','TOT_DT','TOT_K'] # List of total stats """"""

# %%
db = sql.connect('nfl_draft_analysis.db') # Establish Database connection

xlsx = pd.ExcelFile('nfl_draft_analysis.xlsx') # Load Excel file
for sheet in avg_stats + total_stats:
    
    df = pd.read_excel(xlsx, sheet_name = sheet) # Creates a Data Frame from each Excel sheet
    df.to_sql(sheet, db, index=False, if_exists='replace') # Pushes each Data Frame as a table in the Database

# %% [markdown]
# Everything above this sets up the DataBase connection and tables

# %%
#### Things to do using SQL
# take average position stats (the important ones)
# take average career stats of each player (the ones that are most important to that position)
# compare the player stats to the average
# for stats that arent important to their position, N/A

# %% [markdown]
# Offensive positions

# %%
#QB
query_QB = """
SELECT
    t.player_name_full,
    t.position,
    t.college,
    t.draft_slot,
    t.round,
    t.pick,

    t.completions,
    a.completions_mean,
    t.completions - a.completions_mean AS completions_diff,

    t.attempts,
    a.attempts_mean,
    t.attempts - a.attempts_mean AS attempts_diff,

    t.passing_yards,
    a.passing_yards_mean,
    t.passing_yards - a.passing_yards_mean AS passing_yards_diff,

    t.passing_tds,
    a.passing_tds_mean,
    t.passing_tds - a.passing_tds_mean AS passing_tds_diff,

    t.passing_interceptions,
    a.passing_interceptions_mean,
    t.passing_interceptions - a.passing_interceptions_mean AS passing_interceptions_diff

FROM TOT_QB t
JOIN AVG_QB a
ON t.draft_slot = a.draft_slot
"""

df_qb = pd.read_sql(query_QB, db)

df_qb.head()
# Out:
#   player_name_full position           college  draft_slot  round  pick  \
# 0      Andre Smith       QB    North Carolina           6      7   234
# 1    Amari Rodgers       QB           Clemson           3      3    85
# 2     Tre' Jackson       QB       Florida St.           4      4   111
# 3     John Johnson       QB       Boston Col.           3      3    91
# 4    Taywan Taylor       QB  Western Kentucky           3      3    72
#
#    completions  completions_mean  completions_diff  attempts  ...  \
# 0         1349            180.05           1168.95      2044  ...
# 1         2910            485.78           2424.22      4512  ...
# 2            4            627.56           -623.56         6  ...
# 3          112            485.78           -373.78       181  ...
# 4         1035            485.78            549.22      1673  ...
#
#    attempts_diff  passing_yards  passing_yards_mean  passing_yards_diff  \
# ...

# %%
# WR
query_WR = """
SELECT
    t.player_name_full,
    t.position,
    t.college,
    t.draft_slot,
    t.round,
    t.pick,

    t.receptions,
    a.receptions_mean,
    t.receptions - a.receptions_mean AS receptions_diff,

    t.targets,
    a.targets_mean,
    t.targets - a.targets_mean AS targets_diff,

    t.receiving_yards,
    a.receiving_yards_mean,
    t.receiving_yards - a.receiving_yards_mean AS receiving_yards_diff,

    t.receiving_tds,
    a.receiving_tds_mean,
    t.receiving_tds - a.receiving_tds_mean AS receiving_tds_diff,

    t.receiving_air_yards,
    a.receiving_air_yards_mean,
    t.receiving_air_yards - a.receiving_air_yards_mean AS receiving_air_yards_diff

FROM TOT_WR t
JOIN AVG_WR a
ON t.draft_slot = a.draft_slot
"""

df_wr = pd.read_sql(query_WR, db)
df_wr.head()
# Out:
#   player_name_full position             college  draft_slot  round  pick  \
# 0     Sutton Smith       WR   Northern Illinois           6      6   175
# 1   Austin Johnson       WR            Penn St.           2      2    43
# 2    Rachaad White       WR         Arizona St.           3      3    91
# 3   Collin Johnson       WR               Texas           5      5   165
# 4       Josh Jones       WR  North Carolina St.           2      2    61
#
#    receptions  receptions_mean  receptions_diff  targets  ...  targets_diff  \
# 0         113            59.67            53.33      169  ...         71.50
# 1          50           136.25           -86.25      100  ...       -118.71
# 2          43           118.55           -75.55       70  ...       -118.60
# 3          88            92.42            -4.42      149  ...          2.05
# 4           0           136.25          -136.25        0  ...       -218.71
#
# ...

# %%
# RB
query_RB = """
SELECT
    t.player_name_full,
    t.position,
    t.college,
    t.draft_slot,
    t.round,
    t.pick,

    t.carries,
    a.carries_mean,
    t.carries - a.carries_mean AS carries_diff,

    t.rushing_yards,
    a.rushing_yards_mean,
    t.rushing_yards - a.rushing_yards_mean AS rushing_yards_diff,

    t.rushing_tds,
    a.rushing_tds_mean,
    t.rushing_tds - a.rushing_tds_mean AS rushing_tds_diff,

    t.receptions,
    a.receptions_mean,
    t.receptions - a.receptions_mean AS receptions_diff,

    t.targets,
    a.targets_mean,
    t.targets - a.targets_mean AS targets_diff

FROM TOT_RB t
JOIN AVG_RB a
ON t.draft_slot = a.draft_slot
"""

df_rb = pd.read_sql(query_RB, db)
df_rb.head()
# Out:
#   player_name_full position            college  draft_slot  round  pick  \
# 0   Daryl Williams       RB           Oklahoma           4      4   102
# 1   Collin Johnson       RB              Texas           5      5   165
# 2      Andre Smith       RB     North Carolina           6      7   234
# 3     Da'Ron Brown       RB  Northern Illinois           6      7   233
# 4      Jaheim Bell       RB        Florida St.           6      7   231
#
#    carries  carries_mean  carries_diff  rushing_yards  ...  \
# 0      157        216.45        -59.45            553  ...
# 1      266        227.65         38.35           1023  ...
# 2       11        136.29       -125.29             58  ...
# 3       59        136.29        -77.29            229  ...
# 4       93        136.29        -43.29            317  ...
#
#    rushing_yards_diff  rushing_tds  rushing_tds_mean  rushing_tds_diff  \
# 0             -334.78            9              5.98              3.02
# ...

# %%
#TE
query_TE = """
SELECT
    t.player_name_full,
    t.position,
    t.college,
    t.draft_slot,
    t.round,
    t.pick,

    t.receptions,
    a.receptions_mean,
    t.receptions - a.receptions_mean AS receptions_diff,

    t.targets,
    a.targets_mean,
    t.targets - a.targets_mean AS targets_diff,

    t.receiving_yards,
    a.receiving_yards_mean,
    t.receiving_yards - a.receiving_yards_mean AS receiving_yards_diff,

    t.receiving_tds,
    a.receiving_tds_mean,
    t.receiving_tds - a.receiving_tds_mean AS receiving_tds_diff,

    t.receiving_air_yards,
    a.receiving_air_yards_mean,
    t.receiving_air_yards - a.receiving_air_yards_mean AS receiving_air_yards_diff

FROM TOT_TE t
JOIN AVG_TE a
ON t.draft_slot = a.draft_slot
"""

df_te = pd.read_sql(query_TE, db)
df_te.head()
# Out:
#   player_name_full position                 college  draft_slot  round  pick  \
# 0    Harlan Miller       TE  Southeastern Louisiana           6      6   205
# 1      Andre Smith       TE          North Carolina           6      7   234
# 2  DeMarcus Walker       TE             Florida St.           2      2    51
# 3  Michael Bennett       TE                Ohio St.           6      6   180
# 4     Khalil Davis       TE                Nebraska           6      6   194
#
#    receptions  receptions_mean  receptions_diff  targets  ...  targets_diff  \
# 0          60            46.39            13.61       81  ...         13.16
# 1           0            46.39           -46.39        2  ...        -65.84
# 2         237           148.79            88.21      353  ...        138.88
# 3         138            46.39            91.61      197  ...        129.16
# 4           3            46.39           -43.39       12  ...        -55.84
#
# ...

# %%
# OLB
query_OLB = """
SELECT
    t.player_name_full,
    t.position,
    t.college,
    t.draft_slot,
    t.round,
    t.pick,

    t.def_tackles_solo,
    a.def_tackles_solo_mean,
    t.def_tackles_solo - a.def_tackles_solo_mean AS def_tackles_solo_diff,

    t.def_sacks,
    a.def_sacks_mean,
    t.def_sacks - a.def_sacks_mean AS def_sacks_diff,

    t.def_qb_hits,
    a.def_qb_hits_mean,
    t.def_qb_hits - a.def_qb_hits_mean AS def_qb_hits_diff,

    t.def_interceptions,
    a.def_interceptions_mean,
    t.def_interceptions - a.def_interceptions_mean AS def_interceptions_diff,

    t.def_tackles_for_loss,
    a.def_tackles_for_loss_mean,
    t.def_tackles_for_loss - a.def_tackles_for_loss_mean AS def_tackles_for_loss_diff

FROM TOT_OLB t
JOIN AVG_OLB a
ON t.draft_slot = a.draft_slot
"""

df_olb = pd.read_sql(query_OLB, db)
df_olb.head()
# Out:
#   player_name_full position           college  draft_slot  round  pick  \
# 0  Jarvis Harrison      OLB         Texas A&M           5      5   152
# 1     D'Joun Smith      OLB  Florida Atlantic           3      3    65
# 2     Trevor Davis      OLB        California           5      5   163
# 3    Jack Anderson      OLB        Texas Tech           6      7   236
# 4  Davontae Harris      OLB      Illinois St.           5      5   151
#
#    def_tackles_solo  def_tackles_solo_mean  def_tackles_solo_diff  def_sacks  \
# 0                55                 130.15                 -75.15       13.0
# 1                68                 116.62                 -48.62        3.0
# 2               291                 130.15                 160.85       11.5
# 3                11                 164.00                -153.00        0.0
# 4               133                 130.15                   2.85        6.5
#
#    ...  def_sacks_diff  def_qb_hits  def_qb_hits_mean  def_qb_hits_diff  \
# ...

# %%
# K
query_K = """
SELECT
    t.player_name_full,
    t.position,
    t.college,
    t.draft_slot,
    t.round,
    t.pick,

    t.fg_made,
    a.fg_made_mean,
    t.fg_made - a.fg_made_mean AS fg_made_diff,

    t.fg_att,
    a.fg_att_mean,
    t.fg_att - a.fg_att_mean AS fg_att_diff,

    t.fg_missed,
    a.fg_missed_mean,
    t.fg_missed - a.fg_missed_mean AS fg_missed_diff,

    t.fg_long,
    a.fg_long_mean,
    t.fg_long - a.fg_long_mean AS fg_long_diff,

    t.pat_made,
    a.pat_made_mean,
    t.pat_made - a.pat_made_mean AS pat_made_diff

FROM TOT_K t
JOIN AVG_K a
ON t.draft_slot = a.draft_slot
"""

df_k = pd.read_sql(query_K, db)
df_k.head()
# Out:
#   player_name_full position           college  draft_slot  round  pick  \
# 0      Maxx Crosby        K  Eastern Michigan           4      4   106
# 1  Harrison Butker        K      Georgia Tech           6      7   233
# 2     Jake Elliott        K           Memphis           5      5   153
# 3    Zane Gonzalez        K       Arizona St.           6      7   224
# 4   Daniel Carlson        K            Auburn           5      5   167
#
#    fg_made  fg_made_mean  fg_made_diff  fg_att  ...  fg_att_diff  fg_missed  \
# 0      188         60.20        127.80     224  ...       151.00         30
# 1      218         84.67        133.33     246  ...       146.44         26
# 2      196        146.00         50.00     231  ...        59.60         32
# 3       96         84.67         11.33     120  ...        20.44         21
# 4      203        146.00         57.00     232  ...        60.60         27
#
#    fg_missed_mean  fg_missed_diff  fg_long  fg_long_mean  fg_long_diff  \
# ...

# %% [markdown]
# Defensive positions

# %%
# FS
query_FS = """
SELECT
    t.player_name_full,
    t.position,
    t.college,
    t.draft_slot,
    t.round,
    t.pick,

    t.def_tackles_solo,
    a.def_tackles_solo_mean,
    t.def_tackles_solo - a.def_tackles_solo_mean AS def_tackles_solo_diff,

    t.def_interceptions,
    a.def_interceptions_mean,
    t.def_interceptions - a.def_interceptions_mean AS def_interceptions_diff,

    t.def_pass_defended,
    a.def_pass_defended_mean,
    t.def_pass_defended - a.def_pass_defended_mean AS def_pass_defended_diff,

    t.def_tackles_for_loss,
    a.def_tackles_for_loss_mean,
    t.def_tackles_for_loss - a.def_tackles_for_loss_mean AS def_tackles_for_loss_diff,

    t.def_qb_hits,
    a.def_qb_hits_mean,
    t.def_qb_hits - a.def_qb_hits_mean AS def_qb_hits_diff

FROM TOT_FS t
JOIN AVG_FS a
ON t.draft_slot = a.draft_slot
"""

df_fs = pd.read_sql(query_FS, db)
df_fs.head()
# Out:
#   player_name_full position             college  draft_slot  round  pick  \
# 0    Rondale Moore       FS              Purdue           2      2    49
# 1     Tyree Wilson       FS          Texas Tech           1      1     7
# 2  Jordan Richards       FS            Stanford           2      2    64
# 3    Juston Burris       FS  North Carolina St.           4      4   118
# 4    Johnny Wilson       FS         Florida St.           6      6   185
#
#    def_tackles_solo  def_tackles_solo_mean  def_tackles_solo_diff  \
# 0                10                 147.29                -137.29
# 1               231                 275.00                 -44.00
# 2                69                 147.29                 -78.29
# 3               117                 204.00                 -87.00
# 4               131                 136.33                  -5.33
#
#    def_interceptions  ...  def_interceptions_diff  def_pass_defended  \
# ...

# %%
# DB
query_DB = """
            SELECT t.player_name_full, 
                    t.position,
                    t.college,
                    t.draft_slot,
                    t.round,
                    t.pick,

                    t.def_tackles_solo,
                    a.def_tackles_solo_mean,
                    (t.def_tackles_solo - a.def_tackles_solo_mean) AS def_tackles_diff,

                    t.def_interceptions,
                    a.def_interceptions_mean,
                    (t.def_interceptions - a.def_interceptions_mean) AS def_interceptions_diff,

                    t.def_pass_defended,
                    a.def_pass_defended_mean,
                    (t.def_pass_defended - a.def_pass_defended_mean) AS def_pass_defended_diff,
                    
                    t.def_sacks,
                    a.def_sacks_mean,
                    (t.def_sacks - a.def_sacks_mean) AS def_sacks_diff,

                    t.def_tackles_for_loss,
                    a.def_tackles_for_loss_mean,
                    (t.def_tackles_for_loss - a.def_tackles_for_loss_mean) AS def_tackles_for_loss_diff

            FROM TOT_DB t
            JOIN AVG_DB a
            ON t.draft_slot = a.draft_slot
        """
df_DB = pd.read_sql(query_DB,db)
df_DB.head()
# Out:
#   player_name_full position        college  draft_slot  round  pick  \
# 0      Aaron Jones       DB  Texas-El Paso           5      5   182
# 1       Logan Hall       DB        Houston           2      2    33
# 2    Johnny Wilson       DB    Florida St.           6      6   185
# 3    Spencer Brown       DB  Northern Iowa           3      3    93
# 4     Tim Williams       DB        Alabama           3      3    78
#
#    def_tackles_solo  def_tackles_solo_mean  def_tackles_diff  \
# 0               133                  54.67             78.33
# 1                96                  53.13             42.87
# 2                24                  32.25             -8.25
# 3                32                  77.31            -45.31
# 4                16                  77.31            -61.31
#
#    def_interceptions  ...  def_interceptions_diff  def_pass_defended  \
# 0                  6  ...                    4.27                 26
# ...

# %%
# CB
query_CB = """
            SELECT t.player_name_full, 
                    t.position,
                    t.college,
                    t.draft_slot,
                    t.round,
                    t.pick,

                    -- Tackles
                    t.def_tackles_solo,
                    a.def_tackles_solo_mean,
                    (t.def_tackles_solo - a.def_tackles_solo_mean) AS def_tackles_diff,

                    -- Interceptions
                    t.def_interceptions,
                    a.def_interceptions_mean,
                    (t.def_interceptions - a.def_interceptions_mean) AS def_interceptions_diff,

                    -- Pass Defended
                    t.def_pass_defended,
                    a.def_pass_defended_mean,
                    (t.def_pass_defended - a.def_pass_defended_mean) AS def_pass_defended_diff,
                    
                    -- Sacks
                    t.def_sacks,
                    a.def_sacks_mean,
                    (t.def_sacks - a.def_sacks_mean) AS def_sacks_diff,
                    
                    -- Tackles for Loss
                    t.def_tackles_for_loss,
                    a.def_tackles_for_loss_mean,
                    (t.def_tackles_for_loss - a.def_tackles_for_loss_mean) AS def_tackles_for_loss_diff

            FROM TOT_CB t
            JOIN AVG_CB a
            ON t.draft_slot = a.draft_slot

            """

df_CB = pd.read_sql(query_CB,db)
df_CB.head()
# Out:
#   player_name_full position         college  draft_slot  round  pick  \
# 0   Cedric Tillman       CB       Tennessee           3      3    74
# 1     Tim Williams       CB         Alabama           3      3    78
# 2      Trent Brown       CB         Florida           6      7   244
# 3      Tre McBride       CB  William & Mary           6      7   245
# 4    Chad Williams       CB   Grambling St.           3      3    98
#
#    def_tackles_solo  def_tackles_solo_mean  def_tackles_diff  \
# 0                34                 116.04            -82.04
# 1               178                 116.04             61.96
# 2                10                  43.73            -33.73
# 3                20                  43.73            -23.73
# 4                29                 116.04            -87.04
#
#    def_interceptions  ...  def_interceptions_diff  def_pass_defended  \
# 0                  2  ...                   -2.26                  7
# ...

# %%
# S
query_S = """
            SELECT t.player_name_full, 
                    t.position,
                    t.college,
                    t.draft_slot,
                    t.round,
                    t.pick,

                    -- Tackles
                    t.def_tackles_solo,
                    a.def_tackles_solo_mean,
                    (t.def_tackles_solo - a.def_tackles_solo_mean) AS def_tackles_diff,

                    -- Interceptions
                    t.def_interceptions,
                    a.def_interceptions_mean,
                    (t.def_interceptions - a.def_interceptions_mean) AS def_interceptions_diff,

                    -- Pass Defended
                    t.def_pass_defended,
                    a.def_pass_defended_mean,
                    (t.def_pass_defended - a.def_pass_defended_mean) AS def_pass_defended_diff,

                    -- Tackles for Loss
                    t.def_tackles_for_loss,
                    a.def_tackles_for_loss_mean,
                    (t.def_tackles_for_loss - a.def_tackles_for_loss_mean) AS def_tackles_for_loss_diff,

                    -- QB Hits
                    t.def_qb_hits,
                    a.def_qb_hits_mean,
                    (t.def_qb_hits - a.def_qb_hits_mean) AS def_qb_hits_diff

            FROM TOT_S t
            JOIN AVG_S a
            ON t.draft_slot = a.draft_slot

            """

df_S = pd.read_sql(query_S,db)
df_S.head()
# Out:
#    player_name_full position          college  draft_slot  round  pick  \
# 0    Deiondre' Hall        S    Northern Iowa           4      4   127
# 1  Malcolm Mitchell        S          Georgia           4      4   112
# 2      Keon Coleman        S      Florida St.           2      2    33
# 3    Khyree Jackson        S           Oregon           4      4   108
# 4       Chris Jones        S  Mississippi St.           2      2    37
#
#    def_tackles_solo  def_tackles_solo_mean  def_tackles_diff  \
# 0                57                 142.00            -85.00
# 1               156                 142.00             14.00
# 2               181                 251.43            -70.43
# 3               458                 142.00            316.00
# 4                49                 251.43           -202.43
#
#    def_interceptions  ...  def_interceptions_diff  def_pass_defended  \
# 0                  0  ...                   -2.89                  5
# ...

# %%
# DT
query_DT = """
                SELECT t.player_name_full, 
                    t.position,
                    t.college,
                    t.draft_slot,
                    t.round,
                    t.pick,

                    -- Tackles
                    t.def_tackles_solo,
                    a.def_tackles_solo_mean,
                    (t.def_tackles_solo - a.def_tackles_solo_mean) AS def_tackles_diff,

                    -- Sacks
                    t.def_sacks,
                    a.def_sacks_mean,
                    (t.def_sacks - a.def_sacks_mean) AS def_sacks_diff,

                    -- QB Hits
                    t.def_qb_hits,
                    a.def_qb_hits_mean,
                    (t.def_qb_hits - a.def_qb_hits_mean) AS def_qb_hits_diff,

                    -- Tackles for Loss
                    t.def_tackles_for_loss,
                    a.def_tackles_for_loss_mean,
                    (t.def_tackles_for_loss - a.def_tackles_for_loss_mean) AS def_tackles_for_loss_diff,

                    -- Fumbles Forced
                    t.def_fumbles_forced,
                    a.def_fumbles_forced_mean,
                    (t.def_fumbles_forced - a.def_fumbles_forced_mean) AS def_fumbles_forced_diff
                
                FROM TOT_DT t
                JOIN AVG_DT a
                ON t.draft_slot = a.draft_slot
            
            """

df_DT = pd.read_sql(query_DT,db)
df_DT.head()
# Out:
#   player_name_full position      college  draft_slot  round  pick  \
# 0  Karlos Williams       DT  Florida St.           5      5   155
# 1    David Edwards       DT    Wisconsin           5      5   169
# 2    Taron Johnson       DT    Weber St.           4      4   121
# 3  Karlos Williams       DT  Florida St.           5      5   155
# 4    Cole McDonald       DT       Hawaii           6      7   224
#
#    def_tackles_solo  def_tackles_solo_mean  def_tackles_diff  def_sacks  ...  \
# 0                15                  42.03            -27.03        0.0  ...
# 1                 6                  42.03            -36.03        1.0  ...
# 2                52                  39.45             12.55       12.0  ...
# 3                60                  42.03             17.97       13.0  ...
# 4                72                  29.14             42.86       10.5  ...
#
#    def_sacks_diff  def_qb_hits  def_qb_hits_mean  def_qb_hits_diff  \
# ...

# %%
# DE
query_DE = """
                SELECT t.player_name_full, 
                    t.position,
                    t.college,
                    t.draft_slot,
                    t.round,
                    t.pick,

                    -- Tackles
                    t.def_tackles_solo,
                    a.def_tackles_solo_mean,
                    (t.def_tackles_solo - a.def_tackles_solo_mean) AS def_tackles_diff,

                    -- Sacks
                    t.def_sacks,
                    a.def_sacks_mean,
                    (t.def_sacks - a.def_sacks_mean) AS def_sacks_diff,

                    -- QB Hits
                    t.def_qb_hits,
                    a.def_qb_hits_mean,
                    (t.def_qb_hits - a.def_qb_hits_mean) AS def_qb_hits_diff,

                    -- Tackles for Loss
                    t.def_tackles_for_loss,
                    a.def_tackles_for_loss_mean,
                    (t.def_tackles_for_loss - a.def_tackles_for_loss_mean) AS def_tackles_for_loss_diff,

                    -- Fumbles Forced
                    t.def_fumbles_forced,
                    a.def_fumbles_forced_mean,
                    (t.def_fumbles_forced - a.def_fumbles_forced_mean) AS def_fumbles_forced_diff

                FROM TOT_DE t
                JOIN AVG_DE a
                ON t.draft_slot = a.draft_slot

            """

df_DE = pd.read_sql(query_DE,db)
df_DE.head()
# Out:
#   player_name_full position         college  draft_slot  round  pick  \
# 0  Jabrill Peppers       DE        Michigan           1      1    25
# 1   Javorius Allen       DE             USC           4      4   125
# 2      Andre Smith       DE  North Carolina           6      7   234
# 3    Maxx Williams       DE       Minnesota           2      2    55
# 4   Collin Johnson       DE           Texas           5      5   165
#
#    def_tackles_solo  def_tackles_solo_mean  def_tackles_diff  def_sacks  ...  \
# 0                70                  98.41            -28.41       34.0  ...
# 1                17                  50.75            -33.75        2.0  ...
# 2                10                  33.21            -23.21        3.0  ...
# 3                16                  61.74            -45.74        4.5  ...
# 4                18                  28.63            -10.63        5.0  ...
#
#    def_sacks_diff  def_qb_hits  def_qb_hits_mean  def_qb_hits_diff  \
# ...

# %%
# ILB
query = """
                SELECT t.player_name_full, 
                    t.position,
                    t.college,
                    t.draft_slot,
                    t.round,
                    t.pick,

                    -- Tackles
                    t.def_tackles_solo,
                    a.def_tackles_solo_mean,
                    (t.def_tackles_solo - a.def_tackles_solo_mean) AS def_tackles_diff,

                    -- Sacks
                    t.def_sacks,
                    a.def_sacks_mean,
                    (t.def_sacks - a.def_sacks_mean) AS def_sacks_diff,

                    -- QB Hits
                    t.def_qb_hits,
                    a.def_qb_hits_mean,
                    (t.def_qb_hits - a.def_qb_hits_mean) AS def_qb_hits_diff,

                    -- Interceptions
                    t.def_interceptions,
                    a.def_interceptions_mean,
                    (t.def_interceptions - a.def_interceptions_mean) AS def_interceptions_diff,

                    -- Tackles for Loss
                    t.def_tackles_for_loss,
                    a.def_tackles_for_loss_mean,
                    (t.def_tackles_for_loss - a.def_tackles_for_loss_mean) AS def_tackles_for_loss_diff,

                    t.def_pass_defended,
                    a.def_pass_defended_mean,
                    (t.def_pass_defended - a.def_pass_defended_mean) AS def_pass_defended_diff

                FROM TOT_ILB t
                JOIN AVG_ILB a
                ON t.draft_slot = a.draft_slot
        """

df_ILB = pd.read_sql(query,db)
df_ILB.head()
# Out:
#    player_name_full position           college  draft_slot  round  pick  \
# 0    Darius Jackson      ILB  Eastern Michigan           6      6   216
# 1   Andrew Ogletree      ILB    Youngstown St.           6      6   192
# 2     Eddie Jackson      ILB           Alabama           4      4   112
# 3      Ramik Wilson      ILB           Georgia           4      4   118
# 4  Tyler Matakevich      ILB            Temple           6      7   246
#
#    def_tackles_solo  def_tackles_solo_mean  def_tackles_diff  def_sacks  ...  \
# 0               129                 141.17            -12.17        4.0  ...
# 1               321                 141.17            179.83        6.0  ...
# 2                47                 226.38           -179.38        2.0  ...
# 3               104                 226.38           -122.38        0.0  ...
# 4                82                 141.17            -59.17        0.0  ...
#
#    def_qb_hits_diff  def_interceptions  def_interceptions_mean  \
# ...

# %%
# LB
query = """ SELECT t.player_name_full, 
                    t.position,
                    t.college,
                    t.draft_slot,
                    t.round,
                    t.pick,

                    -- Tackles
                    t.def_tackles_solo,
                    a.def_tackles_solo_mean,
                    (t.def_tackles_solo - a.def_tackles_solo_mean) AS def_tackles_diff,

                    -- Sacks
                    t.def_sacks,
                    a.def_sacks_mean,
                    (t.def_sacks - a.def_sacks_mean) AS def_sacks_diff,

                    -- QB Hits
                    t.def_qb_hits,
                    a.def_qb_hits_mean,
                    (t.def_qb_hits - a.def_qb_hits_mean) AS def_qb_hits_diff,

                    -- Interceptions
                    t.def_interceptions,
                    a.def_interceptions_mean,
                    (t.def_interceptions - a.def_interceptions_mean) AS def_interceptions_diff,

                    -- Tackles for Loss
                    t.def_tackles_for_loss,
                    a.def_tackles_for_loss_mean,
                    (t.def_tackles_for_loss - a.def_tackles_for_loss_mean) AS def_tackles_for_loss_diff,

                    t.def_pass_defended,
                    a.def_pass_defended_mean,
                    (t.def_pass_defended - a.def_pass_defended_mean) AS def_pass_defended_diff

            FROM TOT_LB t
            JOIN AVG_LB a
            ON t.draft_slot = a.draft_slot

        """

df_LB = pd.read_sql(query,db)
df_LB.head()
# Out:
#    player_name_full position      college  draft_slot  round  pick  \
# 0      Duke Johnson       LB   Miami (FL)           3      3    77
# 1       Byron Jones       LB  Connecticut           1      1    27
# 2    Deshaun Watson       LB      Clemson           1      1    12
# 3  Anthony Bradford       LB          LSU           4      4   108
# 4      John Johnson       LB  Boston Col.           3      3    91
#
#    def_tackles_solo  def_tackles_solo_mean  def_tackles_diff  def_sacks  ...  \
# 0               207                  65.89            141.11        5.0  ...
# 1                 4                  94.07            -90.07        0.0  ...
# 2                23                  94.07            -71.07        3.0  ...
# 3                 5                  55.62            -50.62        0.0  ...
# 4                 2                  65.89            -63.89        0.0  ...
#
#    def_qb_hits_diff  def_interceptions  def_interceptions_mean  \
# ...
